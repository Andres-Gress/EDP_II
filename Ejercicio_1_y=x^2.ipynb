# %% [markdown]
# <a href="https://colab.research.google.com/github/Andres-Gress/EDP_I/blob/main/Ejercicio_1_y%3Dx%5E2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Ejercicio 1. Gráfica $y=x^2$

# %%
import matplotlib.pyplot as plt
import numpy as np

# Crear un rango de valores para x
x = np.linspace(-5, 5, 400)

# Calcular los valores de y para cada x

# Crear la gráfica
plt.plot(x, y, label="y = x^2")

# Etiquetas de los ejes
plt.xlabel("x")
plt.ylabel("y")

# Título de la gráfica
plt.title("Gráfica de y = x^2")

# Mostrar la leyenda
plt.legend()

# Mostr noar la gráfica
plt.grid(True)
plt.show()
